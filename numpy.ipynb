# %% [markdown]
# # Задание к курсам по анализу данных от Mail.ru #

# %% [markdown]
#  ## Библиотека Numpy ##

# %% [markdown]
# **1. Установить нужные библиотеки**
#
# **2. Считать и вывести изображение**
#
# Изображение состоит из трех цветовых каналов в im находится numpy array

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
im = cv2.imread("big.jpg")

plt.imshow(im)
print("Kitty image:")
# Out:
# Kitty image:

# %% [markdown]
# **3. Какого размера изображение?**

# %%
size = im.shape
size
# Out:
# (375, 500, 3)

# %% [markdown]
# Таким образом можем сказать, что изображение размера 375 х 500

# %% [markdown]
# **4. Найдите среднее значению по каждому из каналов**

# %%
midl = im.mean(axis = (0,1))
midl
# Out:
# array([ 49.91059733,  92.14002667, 128.69120533])

# %% [markdown]
# **5. Посчитайте разброс (среднеквадратичное отклонение) значений по каждому из каналов**

# %%
sd = im.std(axis = (1, 0))
sd
# Out:
# array([38.29606242, 62.76430657, 77.48906153])

# %% [markdown]
# **6. Поменяйте каналы исходного изображения в обратном порядке**

# %%
new_im = np.flip(im,axis = 2)
plt.imshow(new_im)
new_im[0,345,0]
# Out:
# 192

# %% [markdown]
# **7. Создать массив numpy:**

# %%
np.random.seed(7964)
A = np.random.randint(0, 8, size=(500, 500)) 
A
# Out:
# array([[5, 6, 2, ..., 1, 4, 2],
#        [6, 3, 4, ..., 2, 3, 5],
#        [1, 2, 5, ..., 6, 3, 1],
#        ...,
#        [1, 3, 4, ..., 4, 7, 0],
#        [1, 3, 7, ..., 2, 4, 4],
#        [5, 7, 6, ..., 7, 4, 2]])

# %% [markdown]
# **8. Сколько столбцов, в которых есть хоть одно значение 7?**

# %%
np.unique((A == 7).nonzero()[1]).shape
# Out:
# (500,)

# %% [markdown]
# **9. Найдите индексы значений, которые меньше 4**

# %%
ind4 = (A < 4).nonzero() 
sum(ind4[0] +ind4[1])
# Out:
# 62383552

# %% [markdown]
# **10. Найдите индексы значений, которые меньше 4 и не меньше 2**

# %%
Ind24 = ((A <4) &(A>=2)).nonzero()
Ind24
sum(Ind24[0] +Ind24[1])
# Out:
# 31139828

# %% [markdown]
# **11. Просуммировать все значения по индексам значений из предыдущего задания.**

# %%
sum(A[Ind24])
# Out:
# 156096

# %% [markdown]
# **12. Найдите максимальное значение в каждом столбце массива.**

# %%
np.amax(A, axis = 1)
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
# ...

# %%
x = np.arange(1, 501, 1)

# %% [markdown]
# **13. Найти скалярное произведение массива A и x.**

# %%
scalar = np.dot(x,A)
np.sum(scalar)
# Out:
# 218913432

# %% [markdown]
# **14. Умножьте массив A на массив w транспонированный. Ответ - сумма значений.**

# %%
np.random.seed(33)
w = np.random.randint(0, 8, size=(5, 500))
P = np.matmul(A, np.transpose(w))

# %%
np.sum(P)
# Out:
# 15215957

# %%
C = A * np.transpose(w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-6fbdef011fe0> in <module>
# ----> 1 C = A * np.transpose(w)
#
# ValueError: operands could not be broadcast together with shapes (500,500) (500,5)
